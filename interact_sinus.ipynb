# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib nbagg 
#matplotlib backend vgl. python 2 matplotlib notebook

# %%
x = np.linspace(0, 2, 1000)
fig, ax = plt.subplots(1, figsize=(9, 5))
plt.suptitle('Wechselspannung in mV')

pi = np.pi #Warum geht das nicht?
sin = np.sin

def interact_plot(amp, phase, freq):
    
    ax.clear() #Bei jeder Änderung der Slider wird neu geplottet, daher muss vorher "radiert" werden
    
    y = amp * np.sin(freq * 2 * np.pi * x + phase * 2 * np.pi)# Allgemeine Formel
    
    units = 'amp = {} $(mV)$ \nphase = {} $(s)$ \nfreq = {} $(Hz)$' # Eine Liste für label mit LaTex
    
    ax.plot(x, y, label=units.format(amp, phase, freq)) #Aufruf plot von x und y, sowie eines Labels mit amp,phase und freq
    ax.set_xlim(x[0], x[-1])
    ax.legend(loc=1)
    ax.set_xlabel('$(s)$')
    ax.set_ylabel('$(mV)$')
    plt.show()


amp = widgets.FloatSlider(min=1, max=10, value=1, description='Amplitude:')
phase = widgets.FloatSlider(min=0, max=5, value=0, description='Phase:')
freq = widgets.FloatSlider(min=1, max=10, value=2, description='Frequenz:')
    
widgets.interactive(interact_plot, amp=amp, phase=phase, freq=freq)
# Out:
# <img src="data:image/png;base64,..." width="900">
# interactive(children=(FloatSlider(value=1.0, description='Amplitude:', max=10.0, min=1.0), FloatSlider(value=0…

# %%
from ipywidgets import *
from IPython.display import display
w = IntSlider()
display(w, w)
# Out:
# IntSlider(value=0)
# IntSlider(value=0)

# %% [markdown]
# # Slider
#
# Why does displaying the same widget twice work?
#
# Widgets are represented in the back-end by a single object. Each time a widget is displayed, a new representation of that same object is created in the front-end. These representations are called views.
#
#  <img src="https://ipywidgets.readthedocs.io/en/latest/_images/WidgetModelView.png" alt="Smiley face" height="420" width="420">

# %%
display(w)
# Out:
# IntSlider(value=38)
