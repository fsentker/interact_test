# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1761">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(-20, 20, 2000)
y0 = np.sin(x)

# %%
p = figure(title="simple line example", plot_height=600, plot_width=900, y_range=(-6,6))
r = p.line(x, y0, color="#2222aa", line_width=2)

r1 = p.line(x, y0, color="#c6dbef", line_width=2)

# %%
def update(f="cos", fr=1, A=1, phi=0, f1="sin", fr1=1, A1=1, phi1=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    
    if   f1 == "sin": func1 = np.sin
    elif f1 == "cos": func1 = np.cos
        
        

    r.data_source.data['y'] = A * func(2*np.pi*fr * x + phi)
    r1.data_source.data['y'] = A1 * func1(2*np.pi*fr1*x + phi1)
    
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
#   <div class="bk-root" id="c7cc20b8-7048-4aa4-9b10-82bb8b20b46a" data-root-id="1762"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
interact(update, f=["sin", "cos"], fr=(0,50), A=(0, 20, 0.1), phi=(0, 20, 0.1), f1=["sin", "cos"], fr1=(0,50), A1=(0, 20, 0.1), phi1=(0, 20, 0.1))
# Out:
# interactive(children=(Dropdown(description='f', index=1, options=('sin', 'cos'), value='cos'), IntSlider(value…
# <function __main__.update(f='cos', fr=1, A=1, phi=0, f1='sin', fr1=1, A1=1, phi1=0)>

# %%
from IPython.display import IFrame

# %%
IFrame('https://fsentker.github.io/time.html', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="https://fsentker.github.io/time.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
